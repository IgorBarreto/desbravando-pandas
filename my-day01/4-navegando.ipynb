# %%
import warnings

warnings.filterwarnings('ignore')
import pandas as pd

# %%
df = pd.read_csv('../data/pedido.csv')

# %%
df.head()
# Out:
#    idPedido                      dtPedido flKetchup             descUF  \
# 0         0  2023-05-11T10:59:33.000+0000       NaN              Goiás
# 1         1  2023-05-11T11:23:42.000+0000       NaN             Paraná
# 2         2  2023-05-11T11:24:29.000+0000       NaN          São Paulo
# 3         3  2023-05-11T11:29:39.000+0000       NaN          São Paulo
# 4         4  2023-05-11T11:31:30.000+0000       NaN  Rio Grande do Sul
#
#                     txtRecado
# 0                         NaN
# 1  Aquela pizza perfeita! :-D
# 2            Muito obrigado!!
# 3                         NaN
# 4        Capricha no peperoni

# %%
df[['idPedido', 'flKetchup']]
# Out:
#       idPedido flKetchup
# 0            0       NaN
# 1            1       NaN
# 2            2       NaN
# 3            3       NaN
# 4            4       NaN
# ...        ...       ...
# 1101      1101      True
# 1102      1102     False
# 1103      1103     False
# 1104      1104      True
# 1105      1105     False
#
# [1106 rows x 2 columns]

# %%
colunas = ['idPedido', 'descUF', 'flKetchup', 'txtRecado', 'dtPedido']
df = df[colunas]
df
# Out:
#       idPedido             descUF flKetchup  \
# 0            0              Goiás       NaN
# 1            1             Paraná       NaN
# 2            2          São Paulo       NaN
# 3            3          São Paulo       NaN
# 4            4  Rio Grande do Sul       NaN
# ...        ...                ...       ...
# 1101      1101            Sergipe      True
# 1102      1102          São Paulo     False
# 1103      1103          São Paulo     False
# 1104      1104          São Paulo      True
# 1105      1105          São Paulo     False
#
#                                               txtRecado  \
# 0                                                   NaN
# 1                            Aquela pizza perfeita! :-D
# 2                                      Muito obrigado!!
# 3                                                   NaN
# 4                                  Capricha no peperoni
# ...                                                 ...
# 1101  Esse formulário deu fome no meio do expediente...
# 1102                                                NaN
# 1103                                    Bastante queijo
# 1104                                                NaN
# 1105      Favor deixar a massa crocante e lave as mãos.
#
#                           dtPedido
# 0     2023-05-11T10:59:33.000+0000
# 1     2023-05-11T11:23:42.000+0000
# 2     2023-05-11T11:24:29.000+0000
# 3     2023-05-11T11:29:39.000+0000
# 4     2023-05-11T11:31:30.000+0000
# ...                            ...
# 1101  2023-05-25T16:47:40.000+0000
# 1102  2023-05-25T16:55:35.000+0000
# 1103  2023-05-25T17:07:05.000+0000
# 1104  2023-05-25T18:18:02.000+0000
# 1105  2023-05-25T18:27:12.000+0000
#
# [1106 rows x 5 columns]

# %% [markdown]
# ### Navegar em linhas

# %%
df_sample = df.sample(100)
df_sample
# Out:
#       idPedido              descUF flKetchup  \
# 16          16           São Paulo     False
# 54          54           São Paulo     False
# 569        569  Mato Grosso do Sul     False
# 680        680              Paraná     False
# 628        628        Minas Gerais     False
# ...        ...                 ...       ...
# 665        665               Bahia      True
# 647        647           São Paulo     False
# 1047      1047           São Paulo     False
# 308        308           São Paulo      True
# 953        953               Ceará      True
#
#                                           txtRecado  \
# 16                                       #VAIIII <3
# 54                                              NaN
# 569    Massa crocante, nada de queimado nas bordas.
# 680                                             NaN
# 628                                             NaN
# ...                                             ...
# 665                                             NaN
# 647   Hipótese 1: alto índice de ketchup em RJ rsrs
# 1047                                            NaN
# 308       Estou ansiosa para comer essa pizza rsrsr
# 953                                            #TMJ
#
#                           dtPedido
# 16    2023-05-11T14:47:39.000+0000
# 54    2023-05-12T20:22:35.000+0000
# 569   2023-05-24T13:39:12.000+0000
# 680   2023-05-24T14:18:32.000+0000
# 628   2023-05-24T13:54:23.000+0000
# ...                            ...
# 665   2023-05-24T14:10:14.000+0000
# 647   2023-05-24T14:03:41.000+0000
# 1047  2023-05-24T22:56:06.000+0000
# 308   2023-05-22T19:33:25.000+0000
# 953   2023-05-24T19:25:46.000+0000
#
# [100 rows x 5 columns]

# %%
df_sample.iloc[0] # Retorna o registro na posição 0
# Out:
# idPedido                               16
# descUF                          São Paulo
# flKetchup                           False
# txtRecado                      #VAIIII <3
# dtPedido     2023-05-11T14:47:39.000+0000
# Name: 16, dtype: object

# %%
df_sample.iloc[[0,2,5,10]]
# Out:
#      idPedido              descUF flKetchup  \
# 16         16           São Paulo     False
# 569       569  Mato Grosso do Sul     False
# 644       644              Paraná      True
# 425       425      Rio de Janeiro      True
#
#                                         txtRecado  \
# 16                                     #VAIIII <3
# 569  Massa crocante, nada de queimado nas bordas.
# 644                              Capricha nessa 🍕
# 425                                           NaN
#
#                          dtPedido
# 16   2023-05-11T14:47:39.000+0000
# 569  2023-05-24T13:39:12.000+0000
# 644  2023-05-24T14:03:01.000+0000
# 425  2023-05-23T13:13:39.000+0000

# %%
df_sample.iloc[0:10][['idPedido','dtPedido']]
# Out:
#      idPedido                      dtPedido
# 16         16  2023-05-11T14:47:39.000+0000
# 54         54  2023-05-12T20:22:35.000+0000
# 569       569  2023-05-24T13:39:12.000+0000
# 680       680  2023-05-24T14:18:32.000+0000
# 628       628  2023-05-24T13:54:23.000+0000
# 644       644  2023-05-24T14:03:01.000+0000
# 574       574  2023-05-24T13:40:02.000+0000
# 488       488  2023-05-23T22:42:55.000+0000
# 199       199  2023-05-16T17:31:20.000+0000
# 284       284  2023-05-19T22:47:16.000+0000
